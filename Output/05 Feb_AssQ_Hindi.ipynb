# %% [markdown]
# Q1. Explain Class and Object with respect to Object-Oriented Programming. Give a suitable example.

# %% [markdown]
# A class is a user-defined blueprint or prototype from which objects are created.
# Object is an instance of a Class

# %%
class Bike():
    def __init__(self,name,gear):
        self.name=name
        self.gear=gear

    def bike_detail(self):
        return self.name,self.gear

# %%
bike1=Bike('TVS',3)

# %%
print('bike1 name :',bike1.name)
print('bike1 gear :',bike1.gear)
# Out:
# bike1 name : TVS
# bike1 gear : 3

# %% [markdown]
# Q2. Name the four pillars of OOPs.

# %% [markdown]
# The four pillars of OOPS  are Inheritance, Polymorphism, Encapsulation and Data Abstraction

# %% [markdown]
# Q3. Explain why the __init__() function is used. Give a suitable example.

# %% [markdown]
# __init__ method in Python is used to initialize objects of a class.
#  It is also called a constructor.

# %%
class Person:

    def __init__(self, name):
        self.name = name

    # Sample Method
    def person_name(self):
        print('Hello,welcome', self.name)


p = Person('rohan')
p.person_name()
# Out:
# Hello,welcome rohan

# %% [markdown]
# Q4. Why self is used in OOPs?

# %% [markdown]
# Self represents the instance of the class. By using the 'self'  we can access the attributes and methods of the class in Python.

# %% [markdown]
# Q5. What is inheritance? Give an example for each type of inheritance.

# %% [markdown]
# Inheritance is a way of representing real-world relationships between the two.
# Inheritance is defined as the mechanism of inheriting the properties of the base class to the child class.

# %%
class Parent:
	def func1(self):
		print("This function is in parent class.")


class Child(Parent):
	def func2(self):
		print("This function is in child class.")

object = Child()
object.func1()
object.func2()
# Out:
# This function is in parent class.
# This function is in child class.
